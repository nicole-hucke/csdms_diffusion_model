# %% [markdown]
# # <u>CSDMS Roadshow</u>
# ## Mark is teaching us how to make a title
# ### Somebody got an error so we are kind of on a break
# This is normal text

# %% [markdown]
# ### This is an unordered list:
# * oal
# * me
# * llamo
# * nicole

# %% [markdown]
# ### This is an ordered list:
# 1. uno
# 2. dos
# 3. tres
# 4. cuatro

# %% [markdown]
# ## Now we are going to be looking at code

# %% [markdown]
# We are saving a integer

# %%
x = 5

# %%
x
# Out:
# 5

# %%
print(x)
# Out:
# 5

# %% [markdown]
# Now we are saving a string

# %%
y = "This is a string"

# %%
y
# Out:
# 'This is a string'

# %%
print(y)
# Out:
# This is a string

# %% [markdown]
# Let's save a float (number with decimals)

# %%
z = 0.75 
z
# Out:
# 0.75

# %% [markdown]
# We can check what type our variables are

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
type(z)
# Out:
# float

# %% [markdown]
# We need to be aware of these types because we cannot multiply or divide a number by a string

# %% [markdown]
# Can I do a int with a float?

# %%
test = x/z

# %%
print(test)
# Out:
# 6.666666666666667

# %%
type(test)
# Out:
# float

# %% [markdown]
# it turned into a float!
